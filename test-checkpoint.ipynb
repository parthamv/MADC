# %%
import import_ipynb
from TopCrypto import topcrypto
from Crypto_History import CryptoHistory
from CryptoCurrent import Cryptocurrent
from CryptoPredict import CryptoPredict
from datetime import datetime
from Crypto_News import Crypto_News
import time, requests, pandas, lxml
from lxml import html
from dateutil.relativedelta import relativedelta
from datetime import datetime
import requests, pandas

# %%
o = topcrypto() 
o.topcoins(10)
# Out:
# Requested file has been saved as 'Top_Cryptocurrency_Data.csv'

# %%
my_string = str(input('Enter start date(yyyy-mm-dd hh:mm): ')) #2022-04-14 18:22
dt_start = datetime.strptime(my_string, "%Y-%m-%d %H:%M")
my_string1 = str(input('Enter end date(yyyy-mm-dd hh:mm): ')) #2022-04-15 18:22
dt_end=datetime.strptime(my_string1, "%Y-%m-%d %H:%M")
start=CryptoHistory.format_date(dt_start)
end=CryptoHistory.format_date(dt_end)
symbol = input("Enter the cryptocurrency symbol (i.e,'CRYPTO_NAME'-USD): ") #BTC-USD
r=CryptoHistory.subdomain(symbol, start, end)
head=CryptoHistory.header_function(r)
base_url = 'https://finance.yahoo.com'
url = base_url + r
data=CryptoHistory.scrape_page(url,head)
data[0].to_csv('Requested_CryptoPr.csv') ##Convert the dataframe to CSV file and store in path.
# Out:
# Enter start date(yyyy-mm-dd hh:mm): 2022-04-14 18:22
# Enter end date(yyyy-mm-dd hh:mm): 2022-04-15 18:22
# Enter the cryptocurrency symbol (i.e,'CRYPTO_NAME'-USD): BTC-USD

# %%
 def CryptoDate():
        
        """
    	Claculates the current time in the system as the end date and the 
        time 60 seconds prior to this as the end date and returns the same.
        
    	"""
        end_date = datetime.today()
        st_date = end_date - relativedelta(seconds = 60)
        return st_date,end_date

# %%
st_date,end_date=CryptoDate()
Cryptocurrent.CryptoMain(st_date,end_date)
# Out:
# The file has been saved to your runtime path.

# %%
crypto=CryptoPredict()
pred=crypto.pricePredict("SOL-USD","30-04-2022")
# Out:
# C:\Users\mandu\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\mandu\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:132: FutureWarning: The 'freq' argument in Timestamp is deprecated and will be removed in a future version.
#   date_key = Timestamp(key, freq=base_index.freq)

# %%
crypto.visualizePredict(pred)

# %%
cryptonews=Crypto_News()
cryptonews.crypto_news("BTC")
# Out:
# [{'uuid': 'c89ccf04-e455-30e6-a020-52462dcf2d06',
#   'title': 'Thematic ETFs ‘add a little bit of sizzle’ to portfolios, strategist says',
#   'publisher': 'Yahoo Finance Video',
#   'link': 'https://finance.yahoo.com/video/thematic-etfs-add-little-bit-195641508.html',
#   'providerPublishTime': 1651175801,
#   'type': 'VIDEO'},
#  {'uuid': 'bdcb957d-fe32-30d1-b5dc-1ba14357cb4e',
#   'title': 'Crypto: IMF warns of cryptocurrency trading risks in emerging markets, bitcoin surpasses $41,000',
#   'publisher': 'Yahoo Finance Video',
#   'link': 'https://finance.yahoo.com/video/crypto-imf-warns-cryptocurrency-trading-161337517.html',
#   'providerPublishTime': 1650384817,
#   'type': 'VIDEO'},
#  {'uuid': 'a057ab55-3543-3a82-8b15-f011863284ee',
#   'title': "ETFs: Investors looking for ‘economic response to inflation,' expert explains",
#   'publisher': 'Yahoo Finance Video',
#   'link': 'https://finance.yahoo.com/video/etfs-investors-looking-economic-response-200305863.html',
#   'providerPublishTime': 1649966585,
#   'type': 'VIDEO'},
#  {'uuid': '4faf206f-8ff2-3a51-810b-d3ef12ca1b00',
#   'title': 'Grayscale® Digital Large Cap Fund, Grayscale® DeFi Fund, and Grayscale® Smart Contract Platform Ex-Ethereum Fund Announce Rebalancing of Funds for First Quarter 2022',
#   'publisher': 'GlobeNewswire',
#   'link': 'https://finance.yahoo.com/news/grayscale-digital-large-cap-fund-123000990.html',
#   'providerPublishTime': 1649248200,
#   'type': 'STORY'},
#  {'uuid': '4354dd3f-a314-3e36-882f-66d990bfa3ef',
#   'title': 'Crypto: 84% of institutional investors see digital assets going mainstream',
#   'publisher': 'Yahoo Finance Video',
#   'link': 'https://finance.yahoo.com/video/crypto-84-institutional-investors-see-160447446.html',
#   'providerPublishTime': 1648656287,
#   'type': 'VIDEO'},
#  {'uuid': 'fac08edb-fe8b-3685-9e10-928830267d40',
#   'title': 'Grayscale Investments® Launches Smart Contract Platform Fund',
#   'publisher': 'GlobeNewswire',
#   'link': 'https://finance.yahoo.com/news/grayscale-investments-launches-smart-contract-123000199.html',
#   'providerPublishTime': 1647952200,
#   'type': 'STORY'},
#  {'uuid': '23df297c-c39e-3853-8d2f-4784e780a7c9',
#   'title': 'Bitcoin flat as stocks open higher',
#   'publisher': 'Yahoo Finance Video',
#   'link': 'https://finance.yahoo.com/video/bitcoin-flat-stocks-open-higher-135405302.html',
#   'providerPublishTime': 1647352445,
#   'type': 'VIDEO'},
#  {'uuid': '4d09a105-1331-3aff-8493-22889a395f97',
#   'title': 'Retirement: The pros and cons of adding crypto to your 401(k) plan',
#   'publisher': 'Yahoo Finance Video',
#   'link': 'https://finance.yahoo.com/video/retirement-pros-cons-adding-crypto-221036627.html',
#   'providerPublishTime': 1647036636,
#   'type': 'VIDEO'}]

# %%
cryptonews.crypto_news_df("BTC")
# Out:
#                                    uuid  \
# 0  c89ccf04-e455-30e6-a020-52462dcf2d06
# 1  bdcb957d-fe32-30d1-b5dc-1ba14357cb4e
# 2  a057ab55-3543-3a82-8b15-f011863284ee
# 3  4faf206f-8ff2-3a51-810b-d3ef12ca1b00
# 4  4354dd3f-a314-3e36-882f-66d990bfa3ef
# 5  fac08edb-fe8b-3685-9e10-928830267d40
# 6  23df297c-c39e-3853-8d2f-4784e780a7c9
# 7  4d09a105-1331-3aff-8493-22889a395f97
#
#                                                title            publisher  \
# 0  Thematic ETFs ‘add a little bit of sizzle’ to ...  Yahoo Finance Video
# 1  Crypto: IMF warns of cryptocurrency trading ri...  Yahoo Finance Video
# 2  ETFs: Investors looking for ‘economic response...  Yahoo Finance Video
# 3  Grayscale® Digital Large Cap Fund, Grayscale® ...        GlobeNewswire
# 4  Crypto: 84% of institutional investors see dig...  Yahoo Finance Video
# 5  Grayscale Investments® Launches Smart Contract...        GlobeNewswire
# 6                 Bitcoin flat as stocks open higher  Yahoo Finance Video
# 7  Retirement: The pros and cons of adding crypto...  Yahoo Finance Video
#
#                                                 link  providerPublishTime  \
# 0  https://finance.yahoo.com/video/thematic-etfs-...           1651175801
# 1  https://finance.yahoo.com/video/crypto-imf-war...           1650384817
# 2  https://finance.yahoo.com/video/etfs-investors...           1649966585
# 3  https://finance.yahoo.com/news/grayscale-digit...           1649248200
# 4  https://finance.yahoo.com/video/crypto-84-inst...           1648656287
# 5  https://finance.yahoo.com/news/grayscale-inves...           1647952200
# 6  https://finance.yahoo.com/video/bitcoin-flat-s...           1647352445
# 7  https://finance.yahoo.com/video/retirement-pro...           1647036636
#
#     type
# 0  VIDEO
# 1  VIDEO
# 2  VIDEO
# 3  STORY
# 4  VIDEO
# 5  STORY
# 6  VIDEO
# 7  VIDEO
